# %% [markdown]
# <a href="https://colab.research.google.com/github/Fanigoro/information-retrival/blob/main/scrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.4 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.telkomsel.telkomselcm',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=50, # defaults to 50
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId             userName  \
# 0  56a92e4c-2e85-426e-a7d6-3f1a16c9d8d0              Popey A
# 1  cb2ba7ee-54d9-4c5b-aaea-0ae7e593697b  Yeyen Amne P. Isra'
# 2  c15fcd56-7026-47fe-b705-b479f6afb39e                 PG 1
# 3  b4c06948-0012-4099-b635-04ca3e6778e0         Teo Malatuni
# 4  68c7cd3b-55e7-4c25-b92b-cf11e3e4fd9b       Elisabeth Rani
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Bagus menu sebelumnya sederhana dan mudah dime...      1           3932
# 1  Setelah update dan semua layanan digabung jadi...      1             46
# ...

# %%
len(df_busu.index)
# Out:
# 50

# %%
df_busu[['userName', 'score','at', 'content']].head()
# Out:
#               userName  score                  at  \
# 0              Popey A      1 2024-07-11 13:08:45
# 1  Yeyen Amne P. Isra'      1 2024-09-27 21:14:31
# 2                 PG 1      1 2024-09-28 12:09:46
# 3         Teo Malatuni      1 2024-08-02 05:44:20
# 4       Elisabeth Rani      1 2024-09-19 13:35:03
#
#                                              content
# 0  Bagus menu sebelumnya sederhana dan mudah dime...
# 1  Setelah update dan semua layanan digabung jadi...
# 2  Tampilan ui yang berat, paket data mahal dan p...
# 3  App ini yg mau ditonjolkan fungsinya atau tamp...
# 4  Lebih mudah, efisien dan efektif aplikasi MyIn...

# %%
new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                  userName  score                  at  \
# 2                    PG 1      1 2024-09-28 12:09:46
# 8        Alfiyah Sholihah      1 2024-09-28 11:44:22
# 40            Whesly Pane      1 2024-09-28 11:17:44
# 38  Muhammad Fazeriansyah      1 2024-09-28 07:35:15
# 29  Felix Kristian Nazara      2 2024-09-28 02:49:46
#
#                                               content
# 2   Tampilan ui yang berat, paket data mahal dan p...
# 8   aku pengguna apk ini dari lama, apk dlu itu la...
# 40  Ini jaringannya kok nggak stabil ya.. (tanda p...
# 38  Ada notifikasi verifikasi data tapi sudah seri...
# 29  Bagusan Telkomsel fitur yg dulu lebih sederhan...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']]

# %%
my_df.head()
# Out:
#                  userName  score                  at  \
# 2                    PG 1      1 2024-09-28 12:09:46
# 8        Alfiyah Sholihah      1 2024-09-28 11:44:22
# 40            Whesly Pane      1 2024-09-28 11:17:44
# 38  Muhammad Fazeriansyah      1 2024-09-28 07:35:15
# 29  Felix Kristian Nazara      2 2024-09-28 02:49:46
#
#                                               content
# 2   Tampilan ui yang berat, paket data mahal dan p...
# 8   aku pengguna apk ini dari lama, apk dlu itu la...
# 40  Ini jaringannya kok nggak stabil ya.. (tanda p...
# 38  Ada notifikasi verifikasi data tapi sudah seri...
# 29  Bagusan Telkomsel fitur yg dulu lebih sederhan...

# %%
my_df.to_csv("scrapped_data.csv", index = False)
